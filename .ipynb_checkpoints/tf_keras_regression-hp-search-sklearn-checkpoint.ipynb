# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0-beta0
# sys.version_info(major=3, minor=7, micro=0, releaselevel='final', serial=0)
# matplotlib 3.0.3
# numpy 1.16.0
# pandas 0.24.2
# sklearn 0.21.3
# tensorflow 2.0.0-beta0
# tensorflow.python.keras.api._v2.keras 2.2.4-tf

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    housing.data, housing.target, random_state = 7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state = 11)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
# RandomizedSearchCV
# 1. 转化为sklearn的model
# 2. 定义参数集合
# 3. 搜索参数

def build_model(hidden_layers = 1,
                layer_size = 30,
                learning_rate = 3e-3):
    model = keras.models.Sequential()
    model.add(keras.layers.Dense(layer_size, activation='relu',
                                 input_shape=x_train.shape[1:]))
    for _ in range(hidden_layers - 1):
        model.add(keras.layers.Dense(layer_size,
                                     activation = 'relu'))
    model.add(keras.layers.Dense(1))
    optimizer = keras.optimizers.SGD(learning_rate)
    model.compile(loss = 'mse', optimizer = optimizer)
    return model

sklearn_model = keras.wrappers.scikit_learn.KerasRegressor(
    build_fn = build_model)
callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2)]
history = sklearn_model.fit(x_train_scaled, y_train,
                            epochs = 10,
                            validation_data = (x_valid_scaled, y_valid),
                            callbacks = callbacks)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# 11610/11610 [==============================] - 0s 27us/sample - loss: 1.4655 - val_loss: 0.7348
# Epoch 2/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.7132 - val_loss: 0.6393
# Epoch 3/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.6089 - val_loss: 0.5697
# Epoch 4/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.5289 - val_loss: 0.5301
# Epoch 5/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4881 - val_loss: 0.5129
# Epoch 6/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4732 - val_loss: 0.4952
# Epoch 7/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4632 - val_loss: 0.4863
# Epoch 8/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4510 - val_loss: 0.4750
# Epoch 9/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4452 - val_loss: 0.4669
# Epoch 10/10
# 11610/11610 [==============================] - 0s 20us/sample - loss: 0.4398 - val_loss: 0.4585

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %%
from scipy.stats import reciprocal
# f(x) = 1/(x*log(b/a)) a <= x <= b

param_distribution = {
    "hidden_layers":[1, 2, 3, 4],
    "layer_size": np.arange(1, 100),
    "learning_rate": reciprocal(1e-4, 1e-2),
}

from sklearn.model_selection import RandomizedSearchCV

random_search_cv = RandomizedSearchCV(sklearn_model,
                                      param_distribution,
                                      n_iter = 10,
                                      cv = 3,
                                      n_jobs = 1)
random_search_cv.fit(x_train_scaled, y_train, epochs = 100,
                     validation_data = (x_valid_scaled, y_valid),
                     callbacks = callbacks)

# cross_validation: 训练集分成n份，n-1训练，最后一份验证.
# Out:
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 3.0446 - val_loss: 1.6194
# Epoch 2/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.1222 - val_loss: 0.9351
# Epoch 3/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7979 - val_loss: 0.7786
# Epoch 4/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7055 - val_loss: 0.7226
# Epoch 5/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6624 - val_loss: 0.6878
# Epoch 6/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6342 - val_loss: 0.6621
# Epoch 7/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6126 - val_loss: 0.6422
# Epoch 8/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5945 - val_loss: 0.6250
# Epoch 9/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5784 - val_loss: 0.6093
# Epoch 10/100
# 7740/7740 [==============================] - 0s 28us/sample - loss: 0.5645 - val_loss: 0.5947
# Epoch 11/100
# 7740/7740 [==============================] - 0s 32us/sample - loss: 0.5525 - val_loss: 0.5821
# Epoch 12/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5414 - val_loss: 0.5688
# Epoch 13/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5310 - val_loss: 0.5594
# Epoch 14/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5226 - val_loss: 0.5473
# Epoch 15/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5144 - val_loss: 0.5389
# Epoch 16/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5072 - val_loss: 0.5294
# Epoch 17/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5006 - val_loss: 0.5219
# Epoch 18/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4945 - val_loss: 0.5160
# Epoch 19/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4890 - val_loss: 0.5089
# Epoch 20/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4839 - val_loss: 0.5038
# Epoch 21/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4795 - val_loss: 0.4981
# Epoch 22/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4750 - val_loss: 0.4938
# Epoch 23/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4711 - val_loss: 0.4895
# Epoch 24/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4671 - val_loss: 0.4875
# Epoch 25/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4636 - val_loss: 0.4803
# Epoch 26/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4601 - val_loss: 0.4780
# Epoch 27/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4567 - val_loss: 0.4735
# Epoch 28/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4534 - val_loss: 0.4703
# Epoch 29/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4507 - val_loss: 0.4662
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4477 - val_loss: 0.4639
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4449 - val_loss: 0.4611
# Epoch 32/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4420 - val_loss: 0.4578
# Epoch 33/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4391 - val_loss: 0.4545
# Epoch 34/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4368 - val_loss: 0.4526
# Epoch 35/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4344 - val_loss: 0.4499
# Epoch 36/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4320 - val_loss: 0.4475
# Epoch 37/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4297 - val_loss: 0.4456
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4274 - val_loss: 0.4440
# Epoch 39/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4256 - val_loss: 0.4411
# Epoch 40/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4236 - val_loss: 0.4397
# Epoch 41/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4218 - val_loss: 0.4372
# Epoch 42/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4198 - val_loss: 0.4344
# Epoch 43/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.4183 - val_loss: 0.4340
# Epoch 44/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4164 - val_loss: 0.4313
# Epoch 45/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4151 - val_loss: 0.4304
# Epoch 46/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4134 - val_loss: 0.4286
# Epoch 47/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4121 - val_loss: 0.4275
# Epoch 48/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4108 - val_loss: 0.4259
# 3870/3870 [==============================] - 0s 10us/sample - loss: 0.3861
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 2.8027 - val_loss: 1.1537
# Epoch 2/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.9517 - val_loss: 0.8353
# Epoch 3/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7959 - val_loss: 0.7755
# Epoch 4/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7376 - val_loss: 0.7440
# Epoch 5/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7032 - val_loss: 0.7203
# Epoch 6/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6777 - val_loss: 0.7007
# Epoch 7/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6569 - val_loss: 0.6822
# Epoch 8/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6388 - val_loss: 0.6655
# Epoch 9/100
# 7740/7740 [==============================] - ETA: 0s - loss: 0.616 - 0s 24us/sample - loss: 0.6222 - val_loss: 0.6505
# Epoch 10/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6075 - val_loss: 0.6356
# Epoch 11/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5935 - val_loss: 0.6224
# Epoch 12/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5806 - val_loss: 0.6094
# Epoch 13/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5687 - val_loss: 0.5974
# Epoch 14/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5573 - val_loss: 0.5859
# Epoch 15/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5464 - val_loss: 0.5751
# Epoch 16/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5368 - val_loss: 0.5653
# Epoch 17/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5277 - val_loss: 0.5561
# Epoch 18/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5197 - val_loss: 0.5479
# Epoch 19/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5120 - val_loss: 0.5401
# Epoch 20/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5048 - val_loss: 0.5328
# Epoch 21/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4982 - val_loss: 0.5255
# Epoch 22/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4920 - val_loss: 0.5193
# Epoch 23/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4862 - val_loss: 0.5129
# Epoch 24/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4810 - val_loss: 0.5071
# Epoch 25/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4756 - val_loss: 0.5015
# Epoch 26/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4710 - val_loss: 0.4967
# Epoch 27/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4665 - val_loss: 0.4914
# Epoch 28/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4620 - val_loss: 0.4868
# Epoch 29/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4581 - val_loss: 0.4823
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4541 - val_loss: 0.4781
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4503 - val_loss: 0.4739
# Epoch 32/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4463 - val_loss: 0.4705
# Epoch 33/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4433 - val_loss: 0.4666
# Epoch 34/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4399 - val_loss: 0.4633
# Epoch 35/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4367 - val_loss: 0.4600
# Epoch 36/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4336 - val_loss: 0.4567
# Epoch 37/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4310 - val_loss: 0.4530
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4280 - val_loss: 0.4505
# Epoch 39/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4255 - val_loss: 0.4481
# Epoch 40/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4229 - val_loss: 0.4450
# Epoch 41/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4203 - val_loss: 0.4423
# Epoch 42/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4179 - val_loss: 0.4397
# Epoch 43/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4161 - val_loss: 0.4371
# Epoch 44/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4138 - val_loss: 0.4347
# Epoch 45/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4116 - val_loss: 0.4329
# Epoch 46/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4099 - val_loss: 0.4304
# Epoch 47/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4077 - val_loss: 0.4282
# Epoch 48/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4059 - val_loss: 0.4265
# Epoch 49/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4040 - val_loss: 0.4245
# Epoch 50/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4021 - val_loss: 0.4222
# Epoch 51/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4006 - val_loss: 0.4206
# 3870/3870 [==============================] - 0s 10us/sample - loss: 0.3992
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 36us/sample - loss: 2.4804 - val_loss: 1.3926
# Epoch 2/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.9882 - val_loss: 0.8810
# Epoch 3/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7185 - val_loss: 0.7362
# Epoch 4/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6354 - val_loss: 0.6827
# Epoch 5/100
# 7740/7740 [==============================] - 0s 31us/sample - loss: 0.5997 - val_loss: 0.6526
# Epoch 6/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5774 - val_loss: 0.6322
# Epoch 7/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5603 - val_loss: 0.6144
# Epoch 8/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5462 - val_loss: 0.6002
# Epoch 9/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5347 - val_loss: 0.5868
# Epoch 10/100
# 7740/7740 [==============================] - ETA: 0s - loss: 0.522 - 0s 24us/sample - loss: 0.5243 - val_loss: 0.5753
# Epoch 11/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5156 - val_loss: 0.5657
# Epoch 12/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5073 - val_loss: 0.5561
# Epoch 13/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4999 - val_loss: 0.5480
# Epoch 14/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4932 - val_loss: 0.5406
# Epoch 15/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4870 - val_loss: 0.5331
# Epoch 16/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4814 - val_loss: 0.5261
# Epoch 17/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4760 - val_loss: 0.5200
# Epoch 18/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4706 - val_loss: 0.5140
# Epoch 19/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4660 - val_loss: 0.5084
# Epoch 20/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4613 - val_loss: 0.5033
# Epoch 21/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4569 - val_loss: 0.4985
# Epoch 22/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4526 - val_loss: 0.4930
# Epoch 23/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4486 - val_loss: 0.4887
# Epoch 24/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4448 - val_loss: 0.4849
# Epoch 25/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4412 - val_loss: 0.4807
# Epoch 26/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4375 - val_loss: 0.4772
# Epoch 27/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4343 - val_loss: 0.4722
# Epoch 28/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4310 - val_loss: 0.4686
# Epoch 29/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4279 - val_loss: 0.4653
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4248 - val_loss: 0.4619
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4215 - val_loss: 0.4589
# Epoch 32/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4186 - val_loss: 0.4554
# Epoch 33/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4163 - val_loss: 0.4524
# Epoch 34/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4136 - val_loss: 0.4495
# Epoch 35/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.4110 - val_loss: 0.4463
# Epoch 36/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4086 - val_loss: 0.4439
# Epoch 37/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4062 - val_loss: 0.4409
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4037 - val_loss: 0.4392
# Epoch 39/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.4017 - val_loss: 0.4369
# Epoch 40/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3996 - val_loss: 0.4338
# Epoch 41/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3975 - val_loss: 0.4321
# Epoch 42/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3955 - val_loss: 0.4300
# Epoch 43/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3938 - val_loss: 0.4273
# Epoch 44/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3917 - val_loss: 0.4251
# Epoch 45/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.3900 - val_loss: 0.4244
# 3870/3870 [==============================] - 0s 10us/sample - loss: 0.4343
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 41us/sample - loss: 3.8124 - val_loss: 2.7778
# Epoch 2/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 2.0916 - val_loss: 1.8363
# Epoch 3/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.5600 - val_loss: 1.5366
# Epoch 4/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3956 - val_loss: 1.4374
# Epoch 5/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3444 - val_loss: 1.4036
# Epoch 6/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3285 - val_loss: 1.3915
# Epoch 7/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3237 - val_loss: 1.3870
# Epoch 8/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3221 - val_loss: 1.3848
# Epoch 9/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3217 - val_loss: 1.3839
# Epoch 10/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3215 - val_loss: 1.3835
# Epoch 11/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3215 - val_loss: 1.3832
# 3870/3870 [==============================] - 0s 11us/sample - loss: 1.2980
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 40us/sample - loss: 3.7949 - val_loss: 2.7839
# Epoch 2/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 2.0801 - val_loss: 1.8407
# Epoch 3/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.5485 - val_loss: 1.5374
# Epoch 4/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3834 - val_loss: 1.4376
# Epoch 5/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3328 - val_loss: 1.4043
# Epoch 6/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3174 - val_loss: 1.3919
# Epoch 7/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3126 - val_loss: 1.3874
# Epoch 8/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3111 - val_loss: 1.3853
# Epoch 9/100
# 7740/7740 [==============================] - 0s 26us/sample - loss: 1.3106 - val_loss: 1.3843
# Epoch 10/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3105 - val_loss: 1.3839
# Epoch 11/100
# 7740/7740 [==============================] - 0s 26us/sample - loss: 1.3104 - val_loss: 1.3835
# 3870/3870 [==============================] - 0s 10us/sample - loss: 1.3200
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 39us/sample - loss: 3.7770 - val_loss: 2.7902
# Epoch 2/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 2.0729 - val_loss: 1.8462
# Epoch 3/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.5453 - val_loss: 1.5427
# Epoch 4/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3824 - val_loss: 1.4418
# Epoch 5/100
# 7740/7740 [==============================] - ETA: 0s - loss: 1.339 - 0s 25us/sample - loss: 1.3319 - val_loss: 1.4066
# Epoch 6/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3161 - val_loss: 1.3936
# Epoch 7/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3113 - val_loss: 1.3884
# Epoch 8/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3097 - val_loss: 1.3861
# Epoch 9/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3093 - val_loss: 1.3851
# Epoch 10/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3091 - val_loss: 1.3844
# Epoch 11/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 1.3091 - val_loss: 1.3841
# 3870/3870 [==============================] - 0s 10us/sample - loss: 1.3229
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 5.0603 - val_loss: 4.5404
# Epoch 2/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 3.7953 - val_loss: 3.4882
# Epoch 3/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 2.9481 - val_loss: 2.7470
# Epoch 4/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 2.3445 - val_loss: 2.2129
# Epoch 5/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.9170 - val_loss: 1.8342
# Epoch 6/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.6135 - val_loss: 1.5669
# Epoch 7/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.3979 - val_loss: 1.3766
# Epoch 8/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.2443 - val_loss: 1.2424
# Epoch 9/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 1.1342 - val_loss: 1.1476
# Epoch 10/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.0529 - val_loss: 1.0773
# Epoch 11/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.9934 - val_loss: 1.0257
# Epoch 12/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.9475 - val_loss: 0.9860
# Epoch 13/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.9108 - val_loss: 0.9551
# Epoch 14/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.8824 - val_loss: 0.9305
# Epoch 15/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.8597 - val_loss: 0.9105
# Epoch 16/100
# 7740/7740 [==============================] - ETA: 0s - loss: 0.831 - 0s 23us/sample - loss: 0.8416 - val_loss: 0.8940
# Epoch 17/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.8264 - val_loss: 0.8794
# Epoch 18/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.8135 - val_loss: 0.8669
# Epoch 19/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.8024 - val_loss: 0.8558
# Epoch 20/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7926 - val_loss: 0.8458
# Epoch 21/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7838 - val_loss: 0.8366
# Epoch 22/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7759 - val_loss: 0.8281
# Epoch 23/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7687 - val_loss: 0.8202
# Epoch 24/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7619 - val_loss: 0.8128
# Epoch 25/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7557 - val_loss: 0.8059
# Epoch 26/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7498 - val_loss: 0.7994
# Epoch 27/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7442 - val_loss: 0.7932
# Epoch 28/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7389 - val_loss: 0.7873
# Epoch 29/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7339 - val_loss: 0.7817
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7290 - val_loss: 0.7762
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7243 - val_loss: 0.7709
# Epoch 32/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7198 - val_loss: 0.7658
# Epoch 33/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7154 - val_loss: 0.7609
# Epoch 34/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7112 - val_loss: 0.7562
# Epoch 35/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7070 - val_loss: 0.7516
# Epoch 36/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7030 - val_loss: 0.7471
# Epoch 37/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6990 - val_loss: 0.7427
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6952 - val_loss: 0.7385
# Epoch 39/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6914 - val_loss: 0.7343
# Epoch 40/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6878 - val_loss: 0.7303
# Epoch 41/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6842 - val_loss: 0.7263
# Epoch 42/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6806 - val_loss: 0.7224
# Epoch 43/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6772 - val_loss: 0.7186
# Epoch 44/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6738 - val_loss: 0.7148
# Epoch 45/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6705 - val_loss: 0.7112
# Epoch 46/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6672 - val_loss: 0.7076
# Epoch 47/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6640 - val_loss: 0.7040
# Epoch 48/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6608 - val_loss: 0.7006
# Epoch 49/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6577 - val_loss: 0.6972
# Epoch 50/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6547 - val_loss: 0.6939
# Epoch 51/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6517 - val_loss: 0.6906
# Epoch 52/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6487 - val_loss: 0.6874
# Epoch 53/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.
100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7588 - val_loss: 0.8619
# Epoch 15/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7311 - val_loss: 0.8336
# Epoch 16/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7084 - val_loss: 0.8096
# Epoch 17/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6897 - val_loss: 0.7890
# Epoch 18/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6741 - val_loss: 0.7715
# Epoch 19/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6611 - val_loss: 0.7562
# Epoch 20/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6501 - val_loss: 0.7428
# Epoch 21/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6407 - val_loss: 0.7313
# Epoch 22/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6325 - val_loss: 0.7210
# Epoch 23/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6254 - val_loss: 0.7117
# Epoch 24/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6190 - val_loss: 0.7032
# Epoch 25/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6133 - val_loss: 0.6956
# Epoch 26/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6082 - val_loss: 0.6886
# Epoch 27/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6034 - val_loss: 0.6822
# Epoch 28/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5991 - val_loss: 0.6763
# Epoch 29/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5950 - val_loss: 0.6709
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5912 - val_loss: 0.6658
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5875 - val_loss: 0.6609
# Epoch 32/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5841 - val_loss: 0.6565
# Epoch 33/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5808 - val_loss: 0.6523
# Epoch 34/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5777 - val_loss: 0.6482
# Epoch 35/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5747 - val_loss: 0.6446
# Epoch 36/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5718 - val_loss: 0.6408
# Epoch 37/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5690 - val_loss: 0.6370
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5664 - val_loss: 0.6338
# Epoch 39/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5638 - val_loss: 0.6305
# Epoch 40/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.5613 - val_loss: 0.6275
# Epoch 41/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5589 - val_loss: 0.6244
# Epoch 42/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5565 - val_loss: 0.6213
# Epoch 43/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5542 - val_loss: 0.6185
# Epoch 44/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5520 - val_loss: 0.6158
# Epoch 45/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5499 - val_loss: 0.6133
# Epoch 46/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5478 - val_loss: 0.6109
# Epoch 47/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5458 - val_loss: 0.6084
# Epoch 48/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5438 - val_loss: 0.6058
# Epoch 49/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5419 - val_loss: 0.6036
# Epoch 50/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5400 - val_loss: 0.6014
# Epoch 51/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5382 - val_loss: 0.5989
# Epoch 52/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5365 - val_loss: 0.5969
# Epoch 53/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5347 - val_loss: 0.5948
# Epoch 54/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.5331 - val_loss: 0.5925
# Epoch 55/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5314 - val_loss: 0.5905
# Epoch 56/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.5298 - val_loss: 0.5885
# Epoch 57/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5283 - val_loss: 0.5865
# Epoch 58/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5268 - val_loss: 0.5849
# Epoch 59/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5253 - val_loss: 0.5832
# Epoch 60/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5239 - val_loss: 0.5813
# Epoch 61/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5225 - val_loss: 0.5797
# Epoch 62/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5212 - val_loss: 0.5779
# 3870/3870 [==============================] - 0s 10us/sample - loss: 0.5220
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 4.9730 - val_loss: 4.4737
# Epoch 2/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 3.9172 - val_loss: 3.5801
# Epoch 3/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 3.1895 - val_loss: 2.9609
# Epoch 4/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 2.6650 - val_loss: 2.5121
# Epoch 5/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 2.2889 - val_loss: 2.1901
# Epoch 6/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 2.0070 - val_loss: 1.9490
# Epoch 7/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.7879 - val_loss: 1.7578
# Epoch 8/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.6115 - val_loss: 1.6035
# Epoch 9/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.4659 - val_loss: 1.4751
# Epoch 10/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.3441 - val_loss: 1.3656
# Epoch 11/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.2430 - val_loss: 1.2734
# Epoch 12/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.1577 - val_loss: 1.1941
# Epoch 13/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 1.0855 - val_loss: 1.1249
# Epoch 14/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 1.0229 - val_loss: 1.0647
# Epoch 15/100
# 7740/7740 [==============================] - 0s 28us/sample - loss: 0.9689 - val_loss: 1.0123
# Epoch 16/100
# 7740/7740 [==============================] - 0s 27us/sample - loss: 0.9227 - val_loss: 0.9666
# Epoch 17/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.8822 - val_loss: 0.9267
# Epoch 18/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.8470 - val_loss: 0.8919
# Epoch 19/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.8161 - val_loss: 0.8615
# Epoch 20/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7892 - val_loss: 0.8349
# Epoch 21/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7654 - val_loss: 0.8115
# Epoch 22/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7445 - val_loss: 0.7907
# Epoch 23/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.7260 - val_loss: 0.7725
# Epoch 24/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.7094 - val_loss: 0.7564
# Epoch 25/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6947 - val_loss: 0.7420
# Epoch 26/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6816 - val_loss: 0.7294
# Epoch 27/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6698 - val_loss: 0.7181
# Epoch 28/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6592 - val_loss: 0.7080
# Epoch 29/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6496 - val_loss: 0.6988
# Epoch 30/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6408 - val_loss: 0.6907
# Epoch 31/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6328 - val_loss: 0.6832
# Epoch 32/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6255 - val_loss: 0.6765
# Epoch 33/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6189 - val_loss: 0.6704
# Epoch 34/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.6129 - val_loss: 0.6648
# Epoch 35/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.6073 - val_loss: 0.6596
# Epoch 36/100
# 7740/7740 [==============================] - 0s 26us/sample - loss: 0.6020 - val_loss: 0.6548
# Epoch 37/100
# 7740/7740 [==============================] - 0s 31us/sample - loss: 0.5971 - val_loss: 0.6503
# Epoch 38/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5925 - val_loss: 0.6461
# Epoch 39/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5883 - val_loss: 0.6421
# Epoch 40/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5842 - val_loss: 0.6384
# Epoch 41/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.5804 - val_loss: 0.6348
# Epoch 42/100
# 7740/7740 [==============================] - 0s 28us/sample - loss: 0.5768 - val_loss: 0.6314
# Epoch 43/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 0.5734 - val_loss: 0.6282
# Epoch 44/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5701 - val_loss: 0.6250
# Epoch 45/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5670 - val_loss: 0.6220
# Epoch 46/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5640 - val_loss: 0.6191
# Epoch 47/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5611 - val_loss: 0.6163
# Epoch 48/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5584 - val_loss: 0.6136
# Epoch 49/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5558 - val_loss: 0.6110
# Epoch 50/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5532 - val_loss: 0.6084
# Epoch 51/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5508 - val_loss: 0.6059
# Epoch 52/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5484 - val_loss: 0.6035
# Epoch 53/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5461 - val_loss: 0.6011
# Epoch 54/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5438 - val_loss: 0.5988
# Epoch 55/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5417 - val_loss: 0.5964
# Epoch 56/100
# 7740/7740 [==============================] - 0s 23us/sample - loss: 0.5396 - val_loss: 0.5942
# Epoch 57/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5375 - val_loss: 0.5920
# Epoch 58/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5355 - val_loss: 0.5899
# Epoch 59/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5335 - val_loss: 0.5877
# Epoch 60/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5316 - val_loss: 0.5856
# Epoch 61/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5297 - val_loss: 0.5835
# Epoch 62/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5279 - val_loss: 0.5815
# Epoch 63/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5260 - val_loss: 0.5795
# Epoch 64/100
# 7740/7740 [==============================] - 0s 25us/sample - loss: 0.5243 - val_loss: 0.5776
# Epoch 65/100
# 7740/7740 [==============================] - 0s 24us/sample - loss: 0.5225 - val_loss: 0.5757
# 3870/3870 [==============================] - 0s 10us/sample - loss: 0.5733
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 43us/sample - loss: 1.4866 - val_loss: 0.7676
# Epoch 2/100
# 7740/7740 [==============================] - 0s 27us/sample - loss: 0.6689 - val_loss: 0.6522
# Epoch 3/100
# 7740/7740 [==============================] - 0s 28us/sample - loss: 0.5989 - val_loss: 0.5967
# Epoch 4/100
# 7740/7740 [==============================] - 0s 28us/sample - loss: 0.5508 - val_loss: 0.5524
# Epoch 5/100
# 7740/7740 [==============================] - 0s 27us/sample - loss: 0
# Epoch 36/100
# 7740/7740 [==============================] - 0s 33us/sample - loss: 0.3576 - val_loss: 0.3700
# Epoch 37/100
# 7740/7740 [==============================] - 0s 35us/sample - loss: 0.3565 - val_loss: 0.3692
# Epoch 38/100
# 7740/7740 [==============================] - 0s 31us/sample - loss: 0.3547 - val_loss: 0.3671
# 3870/3870 [==============================] - 0s 13us/sample - loss: 0.3522
# Train on 7740 samples, validate on 3870 samples
# Epoch 1/100
# 7740/7740 [==============================] - 0s 57us/sample - loss: 1.8763 - val_loss: 0.8883
# Epoch 2/100
# 7740/7740 [==============================] - 0s 40us/sample - loss: 0.8920 - val_loss: 0.6739
# Epoch 3/100
#   32/7740 [..............................] - ETA: 0s - loss: 1.0480
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ff2a3f74f99c> in <module>
#      17 random_search_cv.fit(x_train_scaled, y_train, epochs = 100,
#      18                      validation_data = (x_valid_scaled, y_valid),
# ---> 19                      callbacks = callbacks)
#      20
#      21 # cross_validation: 训练集分成n份，n-1训练，最后一份验证.
#
# d:\python\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# d:\python\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1467         evaluate_candidates(ParameterSampler(
#    1468             self.param_distributions, self.n_iter,
# -> 1469             random_state=self.random_state))
#
# d:\python\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# d:\python\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# d:\python\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# d:\python\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# d:\python\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# d:\python\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# d:\python\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# d:\python\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# d:\python\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# d:\python\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# d:\python\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# d:\python\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     662         validation_steps=validation_steps,
#     663         validation_freq=validation_freq,
# --> 664         steps_name='steps_per_epoch')
#     665
#     666   def evaluate(self,
#
# d:\python\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     381
#     382         # Get outputs.
# --> 383         batch_outs = f(ins_batch)
#     384         if not isinstance(batch_outs, list):
#     385           batch_outs = [batch_outs]
#
# d:\python\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3508         value = math_ops.cast(value, tensor.dtype)
#    3509       converted_inputs.append(value)
# -> 3510     outputs = self._graph_fn(*converted_inputs)
#    3511
#    3512     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# d:\python\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#     570       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     571           list(kwargs.keys()), list(self._arg_keywords)))
# --> 572     return self._call_flat(args)
#     573
#     574   def _filtered_call(self, args, kwargs):
#
# d:\python\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args)
#     669     # Only need to override the gradient in graph mode and when we have outputs.
#     670     if context.executing_eagerly() or not self.outputs:
# --> 671       outputs = self._inference_function.call(ctx, args)
#     672     else:
#     673       self._register_gradient()
#
# d:\python\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args)
#     443             attrs=("executor_type", executor_type,
#     444                    "config_proto", config),
# --> 445             ctx=ctx)
#     446       # Replace empty list with None
#     447       outputs = outputs or None
#
# d:\python\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
print(random_search_cv.best_params_)
print(random_search_cv.best_score_)
print(random_search_cv.best_estimator_)

# %%
model = random_search_cv.best_estimator_.model
model.evaluate(x_test_scaled, y_test)
